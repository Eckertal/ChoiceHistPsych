# %%
import os
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)

# %%
df_aud = pd.read_csv("C://Users//annae//Desktop//ChoiceHistory_Psych//Data//Exp1_auditory//exp1_final.csv")
df_vis = pd.read_csv("C://Users//annae//Desktop//ChoiceHistory_Psych//Data//Exp2_visual//exp2_final.csv")

# %%
df_aud.rename(columns={"evi-1_z": "evidence_1_z"}, inplace=True)

# %%
df_aud_neut = df_aud[df_aud['block_type']==1.0] # neutral
df_vis_neut = df_vis[df_vis['block_type']==1.0] # neutral

df_aud_rep = df_aud[df_aud['block_type']==0.0] # rep
df_vis_rep = df_vis[df_vis['block_type']==0.0]

# %%
df_aud_neut.columns
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'sbj_id',
#        'trial', 'block_type', 'block', 'diff', 'target', 'response', 'cue',
#        'caps', 'pdi', 'motor', 'resp_1', 'stim_1', 'pdi_zscore', 'caps_zscore',
#        'PPS', 'block_type_z', 'diff_z', 'target_z', 'response_z', 'cue_z',
#        'caps_z', 'pdi_z', 'motor_z', 'resp_1_z', 'stim_1_z', 'PPS_z',
#        'motor-1', 'diff-1', 'prev_mot_z', 'prev_diff_z', 'correct', 'evidence',
#        'evi-1', 'evidence_z', 'evidence_1_z'],
#       dtype='object')

# %%
df_aud_neut.to_csv('exp1_neutOnly.csv')
df_aud_rep.to_csv('exp1_repOnly.csv')

df_vis_neut.to_csv('exp2_neutOnly.csv')
df_vis_rep.to_csv('exp2_repOnly.csv')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\annae\\Desktop\\ChoiceHistory_Psych\\revision_SB2'

# %%
df_aud.head()
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     sbj_id  trial  \
# 0             0             0             0           1  2258445.0    2.0
# 1             1             1             1           2  2258445.0    3.0
# 2             2             2             2           3  2258445.0    4.0
# 3             3             3             3           4  2258445.0    5.0
# 4             4             4             4           5  2258445.0    6.0
#
#    block_type  block  diff  target  response  cue  caps  pdi  motor  resp_1  \
# 0         0.0    1.0   2.0     1.0       1.0  1.0   5.0  5.0    0.0     1.0
# 1         0.0    1.0   6.0     1.0       0.0  1.0   5.0  5.0    0.0     1.0
# 2         0.0    1.0   2.0     1.0       1.0  1.0   5.0  5.0    0.0     0.0
# 3         0.0    1.0   6.0     1.0       1.0  1.0   5.0  5.0    0.0     1.0
# 4         0.0    1.0   3.0     1.0       1.0  1.0   5.0  5.0    0.0     1.0
#
# ...

# %%
df_vis.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Trial  Block  block_type  \
# 0             0             0           1      2      1           0
# 1             1             1           2      3      1           0
# 2             2             2           3      4      1           0
# 3             3             3           4      5      1           0
# 4             4             4           5      6      1           0
#
#    coherence  target  response  correct  cueValid  response_key     onset_rdk  \
# 0     0.0315       0         0        1         1             0  1.629810e+09
# 1     0.0005       1         0        0         0             0  1.629810e+09
# 2     0.0792       1         0        0         1             0  1.629811e+09
# 3     0.0005       1         1        1         1             1  1.629811e+09
# 4     0.0162       1         0        0         0             0  1.629811e+09
#
#         end_rdk    onset_tone  onset_responseWin       rt     key_press  \
# ...
